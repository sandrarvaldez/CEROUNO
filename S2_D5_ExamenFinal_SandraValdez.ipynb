# %% [markdown]
# # Examen Final - Mortalidad Materna
# Introducción
# La base de datos contiene información de los casos de defunción relacionados con la mortalidad materna, esta información es pública.
#
# Reglas:
# Tendrán 3 horas para la realización del examen.
# En cualquier momento, las alumnas podrán tomarse un descanso para ir al baño o para tomar café. En ningún momento se podrá conversar con sus compañeras.
# Pueden usar sus códigos y recursos en línea.
# No pueden trabajar en equipo.
# El resultado de esta evaluación es puramente para encontrar áres de oportunidad en la forma de trabajo de CEROUNO. La calificación obtenida no pone en juego de ninguna manera la permanencia en el programa.
# No se podrá ofrecer ayuda por parte del mentor y del asistente de clase para la solución del examen. Las únicas dudas que podrán ser respondidas son las pertinentes a los secretos del universo.

# %% [markdown]
# ## Parte 1 - Presentación ( 5 puntos )
# Presenta tus resultados en una libreta de Jupyter de manera clara y concisa. Deberás explicar tu método de resolución, el algoritmo, las gráficas y/o DataFrame final y las conclusiones.

# %% [markdown]
# ## Parte 2 - Preámbulo ( 5 puntos )
# Presenta todo lo necesario para comenzar tu análisis de la información. Todo deberá estar comentado para que el usuario final y puede ser entendido

# %%
# Importar librerias necesarias (no importa el orden)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Ejecutar mi base de datos

# %% [markdown]
# ## Parte 3 - Análisis inicial (20 puntos)
#
# - Nombre de los encabezados
# Esta tabla contiene demasiada informacion.
#
# - Muestra un DataFrame que contenga:
# Edad cumplida, Descripción del estado conyugal, Tamaño de localidad, Localidad de ocurrencia, Descrición de la localidad de ocurrencia.Con estos datos pudimos ver la edad promedio de los casos de difuncion materna, los lugares donde hay mas muertes.
# - ¿Cuántas edades diferentes tenían las madres cuando fallecieron? Obten los estadísticos para esta columna y los valores de las edades diferentes.
# Eran 50 edades diferentes y la edad promedio era de 29.
# - Imprime los valores de los años de defunción ¿ Existen datos que son lógicos, es decir, están correctos?
# - ¿Cuántos tipos de escolaridad existen? ¿Hay datos innecesarios o equivocados en la base de datos?
# 12 tipos, si hay muchos datos que son innecesarios.
#
# - ¿Qué entidad tiene mayor número muertes?
# imprimi las entidades, no alcance de tiempo.

# %% [markdown]
# ### Nombre de los encabezados

# %%
# Cargar mi base de datos
BASE=pd.read_csv('mortalidad.csv')

# Ver los env=cabezados de mi base
BASE.head()
# Out:
#    Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0               1972                  6                             JUNIO
# 1               1967                  2                           FEBRERO
# 2               1973                  6                             JUNIO
# 3               1966                  1                             ENERO
# 4               1975                  0                   NO ESPECIFICADO
#
#    Día de nacimiento  Genero Clave de la edad  Edad cumplida  Estado conyugal  \
# 0                 25       2                A             29                5
# 1                  1       2                A             35                5
# 2                 21       2                A             29                5
# 3                 23       2                A             36                5
# 4                  0       2                A             30                5
#
# ...

# %%
#BASE.describe(head)
BASE.columns.values.tolist()
# Out:
# ['Año de nacimiento',
#  'Mes de nacimiento',
#  'Descripción del mes de nacimiento',
#  'Día de nacimiento',
#  'Genero',
#  'Clave de la edad',
#  'Edad cumplida',
#  'Estado conyugal',
#  'Descripción del estado conyugal',
#  'Entidad de residencia',
#  'Descripción de entidad de residencia',
#  'Municipio de residencia',
#  'Descripción del municipio de residencia',
#  'Localidad de residencia',
#  'Descripión de la localidad de residencia',
#  'Tamaño de localidad',
#  'Descripción del tamaño de localidad',
#  'Ocupación habitual',
#  'Descripción de la ocupación habitual',
#  'Escolaridad',
#  'Descripción de la escolaridad',
#  'Derechiahabiencia',
#  'Descrición de la derechiahabiencia',
#  'Entidad de ocurrencia',
#  'Descripción de la entidad de ocurrencia',
#  'Municipio de ocurrencia',
#  'Descrición del municipio de ocurrencia',
#  'Localidad de ocurrencia',
#  'Descrición de la localidad de ocurrencia',
#  'Sitio donde ocurrio la defunción',
# ...

# %% [markdown]
# ### Muestra un DataFrame que contenga: Edad cumplida, Descripción del estado conyugal, Tamaño de localidad, Localidad de ocurrencia, Descrición de la localidad de ocurrencia.

# %%
# Primero eliminare las demas columnas
BASE2=BASE.drop(['Año de nacimiento',
 'Mes de nacimiento',
 'Descripción del mes de nacimiento',
 'Día de nacimiento',
 'Genero',
 'Clave de la edad',
 'Estado conyugal',
 'Entidad de residencia',
 'Descripción de entidad de residencia',
 'Municipio de residencia',
 'Descripción del municipio de residencia',
 'Localidad de residencia',
 'Descripión de la localidad de residencia',
 'Descripción del tamaño de localidad',
 'Ocupación habitual',
 'Descripción de la ocupación habitual',
 'Escolaridad',
 'Descripción de la escolaridad',
 'Derechiahabiencia',
 'Descrición de la derechiahabiencia',
 'Entidad de ocurrencia',
 'Descripción de la entidad de ocurrencia',
 'Municipio de ocurrencia',
 'Descrición del municipio de ocurrencia',
 'Sitio donde ocurrio la defunción',
 'Descripción del sitio donde ocurrio la defunción',
 'Año de la defunción',
 'Mes de la defunción',
 'Descrición del mes de la defunción',
 'Día de la defunción',
 'Hora de la defunción',
 'Minutos de la defunción',
 'Asistencia médica',
 'Descripción de la asistencia médica',
 'Causa CIE a  cuarto dígito',
 'Descrición de la causa CIE',
 'Quien certificó',
 'Descrición de quien certificó',
 'Entidad de registro',
 'Descrición de la entidad de registro',
 'Municipio de registro',
 'Descrición del municipio de registro',
 'Año de registro',
 'Mes de registro',
 'Descripción del mes de registro',
 'Día de registro',
 'Año de la certificación',
 'Mes de la certificación',
 'Descripció del mes de la certificación',
 'Día de la certificación',
 'Año de la base de datos',
 'Razón de mortalidad materna',
 'Descrición de la razón de mortalidad materna'], axis=1)

# %%
# Imprimo mi DataFrame como me lo pidieron
pd.DataFrame(BASE2)
# Out:
#        Edad cumplida Descripción del estado conyugal  Tamaño de localidad  \
# 0                 29                          CASADO                    9
# 1                 35                          CASADO                    9
# 2                 29                          CASADO                    4
# 3                 36                          CASADO                    1
# 4                 30                          CASADO                    0
# 5                 30                          CASADO                    0
# 6                 20                          CASADO                   12
# 7                 27                          CASADO                   15
# 8                 43                          CASADO                    1
# 9                 31                          CASADO                   13
# 10                31                          CASADO                   13
# 11                35                          CASADO                    3
# ...

# %% [markdown]
# ### ¿Cuántas edades diferentes tenían las madres cuando fallecieron?
# Obten los estadísticos para esta columna y los valores de las edades diferentes.

# %%
BASE2['Edad cumplida'].value_counts()
# Out:
# 30     774
# 23     774
# 29     766
# 28     755
# 22     740
# 31     740
# 32     737
# 27     730
# 33     722
# 25     711
# 20     710
# 24     708
# 26     708
# 35     697
# 21     681
# 34     666
# 36     633
# 19     626
# 18     586
# 37     567
# 38     494
# 17     455
# 39     443
# 16     337
# 40     332
# 41     252
# 42     204
# 15     159
# 43     146
# 44      95
# 14      72
# 45      55
# 46      32
# 47      25
# 998     24
# 48      19
# 13      16
# 12       9
# 51       6
# 50       6
# 49       6
# 54       3
# 53       2
# 70       2
# 82       2
# 11       1
# 81       1
# 65       1
# 59       1
# 86       1
# Name: Edad cumplida, dtype: int64

# %%
# Sacar datos estadisticos de la Edad Cumplida
BASE2['Edad cumplida'].describe()
# Out:
# count    17232.000000
# mean        29.765727
# std         36.916010
# min         11.000000
# 25%         22.000000
# 50%         28.000000
# 75%         34.000000
# max        998.000000
# Name: Edad cumplida, dtype: float64

# %%
print(BASE2['Edad cumplida'].unique())
# Out:
# [ 29  35  36  30  20  27  43  31  39  45  42  17  38  26  21  22  40  44
#   34  41  33  13  24  25  37  19  23  32  28 998  15  46  48  16  18  12
#   47  14  51  50  54  49  11  53  81  70  82  59  86  65]

# %%
len(BASE2['Edad cumplida'].unique())
# Out:
# 50

# %% [markdown]
# ### Imprime los valores de los años de defunción ¿ Existen datos que son lógicos, es decir, están correctos?Eliminaremos Edades de 60 años para arriba porque ni son logicos ni correctos

# %%
# Creare otra base de datos que tenga las edades razonables y logicas
EdadRazonable=BASE2[BASE2['Edad cumplida']< 60]
# el numero de registros debe ser menos
len(EdadRazonable)
# Out:
# 17201

# %%
# Aqui estan los datos estadisticos ya modificados, estos son mas razonables.
EdadRazonable.describe()
# Out:
#        Edad cumplida  Tamaño de localidad  Localidad de ocurrencia
# count   17201.000000         17201.000000             17201.000000
# mean       28.395733             7.826987                17.764607
# std         7.372148             5.927327               102.331405
# min        11.000000             0.000000                 0.000000
# 25%        22.000000             2.000000                 1.000000
# 50%        28.000000             7.000000                 1.000000
# 75%        34.000000            14.000000                 1.000000
# max        59.000000            17.000000              3515.000000

# %%
# Todas las edades
print(EdadRazonable['Edad cumplida'].unique())
# Out:
# [29 35 36 30 20 27 43 31 39 45 42 17 38 26 21 22 40 44 34 41 33 13 24 25
#  37 19 23 32 28 15 46 48 16 18 12 47 14 51 50 54 49 11 53 59]

# %%
len(EdadRazonable['Edad cumplida'].unique())
# Out:
# 44

# %%
pd.DataFrame(EdadRazonable)
# Out:
#        Edad cumplida Descripción del estado conyugal  Tamaño de localidad  \
# 0                 29                          CASADO                    9
# 1                 35                          CASADO                    9
# 2                 29                          CASADO                    4
# 3                 36                          CASADO                    1
# 4                 30                          CASADO                    0
# 5                 30                          CASADO                    0
# 6                 20                          CASADO                   12
# 7                 27                          CASADO                   15
# 8                 43                          CASADO                    1
# 9                 31                          CASADO                   13
# 10                31                          CASADO                   13
# 11                35                          CASADO                    3
# ...

# %% [markdown]
# ### ¿Cuántos tipos de escolaridad existen? ¿Hay datos innecesarios o equivocados en la base de datos?
# #### Obtendre estos datos de mi primera base (BASE) porque en la BASE2 me pidieron eliminar esta columna
# En escolaridad no me dice nada, lo encontre en Descripcion de la escolaridad

# %%
len(BASE['Escolaridad'].unique())
#Escolaridad=BASE.set_index('Escolaridad')
# Out:
# 11

# %%
print(BASE['Escolaridad'].unique())
# Out:
# [ 2  4  7  1  5  0 10  3  6 11 12]

# %%
# Cuantos tipos de escolaridad existen? Descripcion de la escolaridad
len(BASE['Descripción de la escolaridad'].unique())
# Out:
# 12

# %%
print(BASE['Descripción de la escolaridad'].unique())
# Out:
# ['PRIMARIA INCOMPLETA' 'SECUNDARIA INCOMPLETA' 'PROFESIONAL' 'NINGUNA'
#  'SECUNDARIA COMPLETA' 'NO ESPECIFICADO' 'POSGRADO' 'PRIMARIA COMPLETA'
#  'BACHILLERATO O PREPARATORIA COMPLETA'
#  'BACHILLERATO O PREPARATORIA INCOMPLETA' 'NO ESPECIFICADO\r\n'
#  'PREESCOLAR']

# %% [markdown]
# ### ¿Qué entidad tiene mayor número muertes?
#
# Aqui estuve investigando donde me aparecia el nombre del municipio

# %%
len(EdadRazonable['Descrición de la localidad de ocurrencia'].unique())
# Out:
# 2904

# %%
EdadRazonable['Descrición de la localidad de ocurrencia'].value_counts()
# Out:
# 140390001 Guadalajara                       550
# 151060001 Toluca de Lerdo                   445
# 211140001 Heróica Puebla de Zaragoza        433
# 090150001 Cuauhtémoc                        286
# 270040001 Villahermosa                      279
# 190390001 Monterrey                         275
# 160530001 Morelia                           256
# 110200001 León de los Aldama                255
# 071010001 Tuxtla Gutiérrez                  237
# 150330001 Ecatepec de Morelos               236
# 200670001 Oaxaca de Juárez                  232
# 310500001 Mérida                            231
# 020040001 Tijuana                           218
# 090020001 Azcapotzalco                      211
# 130480001 Pachuca de Soto                   199
# 120010001 Acapulco de Juárez                199
# 090050001 Gustavo A. Madero                 197
# 220140001 Santiago de Querétaro             196
# 090070001 Iztapalapa                        193
# 080370001 Juárez                            190
# ...

# %%
z=(EdadRazonable['Descrición de la localidad de ocurrencia'].unique())
pd.DataFrame(z)
# Out:
#                                            0
# 0                       311020001 Valladolid
# 1                           310500001 Mérida
# 2                        310560001 Oxkutzcab
# 3                  090160000 No especificado
# 4                  090120000 No especificado
# 5                  150580000 No especificado
# 6              150570001 Naucalpan de Juárez
# 7                        320170001 Guadalupe
# 8                        320560001 Zacatecas
# 9                           030030001 La Paz
# 10              110200001 León de los Aldama
# 11                         160530001 Morelia
# 12                         301180001 Orizaba
# 13                    270040001 Villahermosa
# 14               280220001 Heroica Matamoros
# 15                          070400126 Aztlán
# 16                           180170001 Tepic
# 17           150580001 Ciudad Nezahualcóyotl
# 18       120290001 Chilpancingo de los Bravo
# 19                    151040001 Tlalnepantla
# ...

# %% [markdown]
# ## Parte 4 - Búsqueda de datos (25 puntos + 5 puntos extra )

# %% [markdown]
# ### Imprime 2 DataFrames que sinteticen cierta información.
# Estos DataFrames deberán estar explicados con el contexto y el razón de porque son relevantes.
# Imprime solo el encabezado.
# Puntos extra: Entrega un análisis simple de cada DataFrame

# %%
z1=(EdadRazonable['Descripción del estado conyugal'].unique())
pd.DataFrame(z1)
# Out:
#                                 0
# 0                          CASADO
# 1                       SE IGNORA
# 2                        SEPARADO
# 3                      DIVORCIADO
# 4                     UNION LIBRE
# 5                         SOLTERO
# 6                           VIUDO
# 7  NO APLICA A MENORES DE 12 AÑOS

# %%
# z2=(EdadRazonable['Descripción del estado conyugal'].unique())
EdadRazonable['Descripción del estado conyugal'].value_counts()
#pd.DataFrame(z2)
# Out:
# CASADO                            7642
# UNION LIBRE                       6370
# SOLTERO                           2531
# SE IGNORA                          315
# DIVORCIADO                         142
# VIUDO                              107
# SEPARADO                            93
# NO APLICA A MENORES DE 12 AÑOS       1
# Name: Descripción del estado conyugal, dtype: int64

# %% [markdown]
# ## Parte 5 - Información gráfica (40 puntos + 20 puntos extra)

# %% [markdown]
# ### Realiza un analísis utilizando una gráfica de línea
# ### Realiza un análisis de la relación entre dos variables.
# ### Realizar un análisis donde se necesite usar histogramas.
# ### Presenta un análisis utilizando una gráfica de barras de los indicadores para múltiples paises. (PUNTOS EXTRA)
# Realicen una análisis de correlación para 4 variables (PUNTOS EXTRA) (¿Scatter or density?)
