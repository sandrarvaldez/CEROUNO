# %% [markdown]
# ##  TITHANIC
# ### Relacion entre genero, nivel de boleto y probabilidad de sobrevivir
# ### Explorar

# %%
# Importo Librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# leo mi base de datos
train=pd.read_csv('train.csv')
list(train)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
train.head()
# 0 murio, 1 sobrevivio, SibSp acompa;ado por hermano o esposa, Parch Acompa;ado por padres o hijos.
# Embarked embarcacion donde subieron, pclass 1,2 y 3,
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Que vemos interesante?
# - Relacion entre Nivel de Boletos y Supervivencia
# - Relacion de los que sobrevivieron entre 1a y 2a Clase
# - Relacion entre genero y supervivencia
# - Iban acompa;ados los que murieron
# - Relacion de edad de supervivencia
# - En que puerto subieron
# - Nivel de boleto vs genero
# - Nivel de genero vs edad
# - Precio del boleto por clase y embarcamiento

# %% [markdown]
# ## Relacion entre Nivel de Boletos y Supervivencia

# %%
survived_pclass=train[['Survived','Pclass']]
pd.DataFrame(survived_pclass)
# Out:
#      Survived  Pclass
# 0           0       3
# 1           1       1
# 2           1       3
# 3           1       1
# 4           0       3
# 5           0       3
# 6           0       1
# 7           0       3
# 8           1       3
# 9           1       2
# 10          1       3
# 11          1       1
# 12          0       3
# 13          0       3
# 14          0       3
# 15          1       2
# 16          0       3
# 17          1       2
# 18          0       3
# 19          1       3
# 20          0       2
# 21          1       2
# 22          1       3
# 23          1       1
# 24          0       3
# 25          1       3
# 26          0       3
# 27          0       1
# 28          1       3
# 29          0       3
# ..        ...     ...
# 861         0       2
# 862         1       1
# 863         0       3
# 864         0       2
# 865         1       2
# 866         1       2
# 867         0       1
# 868         0       3
# 869         1       3
# ...

# %%
# LLAMO UNA COLUMNA
train['sex']

# %%
train['sex'].value_counts().plot(kind='bar')

train_femalefamale['Age'].hist()

# %%
# Conteos Iniciales 
primera=len(survived_pclass[survived_pclass['Pclass']==1])
segunda=len(survived_pclass[survived_pclass['Pclass']==2])
tercera=len(survived_pclass[survived_pclass['Pclass']==3])

muertos=len(survived_pclass[survived_pclass['Survived']==0])
sobrevivientes=len(survived_pclass[survived_pclass['Survived']==1])
total=len(survived_pclass['Pclass'])

# %%
print('primera: ', primera, 'segunda: ', segunda, 'tercera: ', tercera, 'muertos:', muertos, 'sobrevivientes: ', sobrevivientes, 'totales', total)
# Out:
# primera:  216 segunda:  184 tercera:  491 muertos: 549 sobrevivientes:  342 totales 891

# %%
survived_pclass=survived_pclass.set_index('Pclass')
pd.DataFrame(survived_pclass)
# Out:
#         Survived
# Pclass
# 3              0
# 1              1
# 3              1
# 1              1
# 3              0
# 3              0
# 1              0
# 3              0
# 3              1
# 2              1
# 3              1
# 1              1
# 3              0
# 3              0
# 3              0
# 2              1
# 3              0
# 2              1
# 3              0
# 3              1
# 2              0
# 2              1
# 3              1
# 1              1
# 3              0
# 3              1
# 3              0
# 1              0
# 3              1
# 3              0
# ...          ...
# 2              0
# 1              1
# 3              0
# 2              0
# 2              1
# 2              1
# 1              0
# 3              0
# 3              1
# 3              0
# 1              1
# 1              0
# 3              0
# 2              1
# 3              1
# 3              0
# 3              0
# 3              0
# 1              1
# 2              1
# ...

# %%
#survived_pclass.plot.bar(x='Pclass', y='Survived')
#plt.show()

# %%
tabla=pd.DataFrame({'XX':['Primera', 'Segunda', 'Tercera'], 'Totales':[primera, segunda, tercera]})
pd.DataFrame(tabla)
# Out:
#         XX  Totales
# 0  Primera      216
# 1  Segunda      184
# 2  Tercera      491

# %%
tabla.plot.bar(x='XX',y='Totales',rot=0)
plt.show()

# %%
tabla.head()
# Out:
#         XX  Totales
# 0  Primera      216
# 1  Segunda      184
# 2  Tercera      491

# %%
survived_pclass.groupby('Pclass')
# te agrupa pero no te lo puedes imaginar  survived_pclass.groupby('Pclass')

# %%
# vamos a agrupar en panditas
agrupados=train.groupby(['Pclass','Survived'])
# aqui me muestra los grupos
agrupados.groups
# Out:
# {(1,
#   0): Int64Index([  6,  27,  30,  34,  35,  54,  62,  64,  83,  92,  96, 102, 110,
#              118, 124, 137, 139, 155, 168, 170, 174, 177, 185, 245, 252, 262,
#              263, 270, 273, 284, 295, 297, 331, 332, 336, 339, 351, 373, 377,
#              434, 438, 452, 456, 462, 467, 475, 487, 492, 493, 498, 505, 515,
#              527, 536, 544, 545, 555, 557, 583, 602, 625, 633, 659, 662, 671,
#              694, 698, 711, 741, 745, 748, 766, 782, 789, 793, 806, 815, 822,
#              867, 872],
#             dtype='int64'),
#  (1, 1): Int64Index([  1,   3,  11,  23,  31,  52,  55,  61,  88,  97,
#              ...
#              842, 849, 853, 856, 857, 862, 871, 879, 887, 889],
#             dtype='int64', length=136),
#  (2,
#   0): Int64Index([ 20,  33,  41,  70,  72,  99, 117, 120, 122, 134, 135, 144, 145,
#              148, 149, 150, 178, 181, 191, 199, 213, 217, 219, 221, 228, 232,
#              234, 236, 238, 239, 242, 249, 265, 277, 292, 308, 312, 314, 317,
# ...

# %%
#tomo el grupito de los ricos y que no se murieron
primera_vivo=agrupados.get_group((1,1))
primera_muerto=agrupados.get_group((1,0))
#imprimo primera vivo, es decir llamo al pandita
agrupados.get_group((1,1))
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 23            24         1       1
# 31            32         1       1
# 52            53         1       1
# 55            56         1       1
# 61            62         1       1
# 88            89         1       1
# 97            98         1       1
# 136          137         1       1
# 151          152         1       1
# 166          167         1       1
# 187          188         1       1
# 194          195         1       1
# 195          196         1       1
# 209          210         1       1
# 215          216         1       1
# 218          219         1       1
# 224          225         1       1
# 230          231         1       1
# 248          249         1       1
# 256          257         1       1
# 257          258         1       1
# 258          259         1       1
# ...

# %%
# Bob construye tabla (()) encerrados en 2 parentesis porque es una tupla

#vivos=[len(agrupados.get_group((1,1)),len(agrupados.get_group((2,1))),len(agrupados.get_group((3,1)))]
#muertos=[len(agrupados.get_group((1,1)),len(agrupados.get_group((2,1)),len(agrupados.get_group((3,1))]

# Bob constrye tabla

Vivos= [len(agrupados.get_group((1,1))),len(agrupados.get_group((2,1))),len(agrupados.get_group((3,1)))]
Muertos=[len(agrupados.get_group((1,0))),len(agrupados.get_group((2,0))),len(agrupados.get_group((3,0)))]
index=['Primera','Segunda','Tercera']

CVM=pd.DataFrame({'Vivos': Vivos,'Muertos': Muertos}, index=index)

# %%
CVM.plot.bar(rot=45)
plt.xlabel('Clase')
plt.ylabel('Personas')
plt.show()

# %%
# Proporciones
# Primera y se murio

p_primera_murio=len(agrupados.get_group((1,0)))/primera
p_primera_vivio=len(agrupados.get_group((1,1)))/primera
p_tercera_murio=len(agrupados.get_group((3,0)))/tercera
p_tercera_vivio=len(agrupados.get_group((3,1)))/tercera

print(p_primera_murio,p_primera_vivio)
print(p_primera_murio,p_tercera_vivio)


#### OJO REVISAR BIEN ESTE CODIGO POR LOS RESULTADOS QUE ME MUESTRA
# Out:
# 0.37037037037037035 0.6296296296296297
# 0.37037037037037035 0.24236252545824846

# %% [markdown]
# ## Histograma tengo un rango, y sobre ese rango mido las frecuencias, histograma no se puede comparar mas de una variable
#
# ## Dispercion, tengo datos numericos (aqui todo es numerico, ordinal; no categorico) valores de un lado, y de otro y los comparo
#
# ## linea: como evoluciona algo (una trayectoria) evolucion del sistema, como se comporta.
#
# ## Barras: Separar en clases y esos tienen diferentes valores (aqui si se puede separar varias variables) frecuencia de alguna caracteristica

# %%
# Edad y precio

# OJO en el COUNT de AGE solo hay 714 DATOS ... Revisar

train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
train['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
train['Age'].plot(kind='hist', bins=30)
plt.show()

# aqui tenemos el total de edades de los pasajeros que iban en el titanic

# %%
# groupby es una condicional 0 muertos 1 vivos
agrupar_edades=train.groupby('Survived')
agrupar_edades.groups
# Out:
# {0: Int64Index([  0,   4,   5,   6,   7,  12,  13,  14,  16,  18,
#              ...
#              877, 878, 881, 882, 883, 884, 885, 886, 888, 890],
#             dtype='int64', length=549),
#  1: Int64Index([  1,   2,   3,   8,   9,  10,  11,  15,  17,  19,
#              ...
#              865, 866, 869, 871, 874, 875, 879, 880, 887, 889],
#             dtype='int64', length=342)}

# %%
# OJO grupo de vivitos con el 0
Muertitos=agrupar_edades.get_group(0)

# %%
Muertitos['Age'].plot(kind='hist',bins=15)
plt.show()

# %%
Muertitos['Age'].describe()
# Out:
# count    424.000000
# mean      30.626179
# std       14.172110
# min        1.000000
# 25%       21.000000
# 50%       28.000000
# 75%       39.000000
# max       74.000000
# Name: Age, dtype: float64

# %%
# OJO grupo de vivitos con el 1 
Vivitos=agrupar_edades.get_group(1)
Vivitos['Age'].plot(kind='hist',bins=15)
plt.show()

# %%
# Estamos revisando edades y tarifa que pagaron
train.plot.scatter('Age','Fare')
plt.show()
