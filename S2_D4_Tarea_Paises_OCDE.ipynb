# %% [markdown]
# # Proyecto Bases de Datos

# %% [markdown]
# #### Puntos extras, yupi!

# %% [markdown]
# ## Parte 1 - Presentación (5 puntos)
#
# Presenta tus resultados en una libreta de Jupyter de manera clara y concisa.
# Deberás explicar:
#    - tu método de resolución
#    - el algoritmo
#    - las gráficas y/o DataFrame final
#    - las conclusiones.
#
#     ### Que voy a hacer?
#
#        - Importar paqueteria cvs
#        - Cargar base de datos
#        - Revisar mis datos columna tras columna para analisar informacion
#        - Limpiare mi base de datos haciendo una copia para no alterar mi base original
#        - Analizare la informacion que me interese

# %%
# Importar librerias necesarias (no importa el orden)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Ejecutar mi base de datos

# %%
# Cargar mi base de datos
OCDE=pd.read_csv('BLI.csv')

# Ver los env=cabezados de mi base
OCDE.head()
# Out:
#   LOCATION         Country INDICATOR                 Indicator MEASURE  \
# 0      AUS       Australia   JE_LMIS  Labour market insecurity       L
# 1      AUT         Austria   JE_LMIS  Labour market insecurity       L
# 2      BEL         Belgium   JE_LMIS  Labour market insecurity       L
# 3      CAN          Canada   JE_LMIS  Labour market insecurity       L
# 4      CZE  Czech Republic   JE_LMIS  Labour market insecurity       L
#
#   Measure INEQUALITY Inequality Unit Code        Unit  PowerCode Code  \
# 0   Value        TOT      Total        PC  Percentage               0
# 1   Value        TOT      Total        PC  Percentage               0
# 2   Value        TOT      Total        PC  Percentage               0
# 3   Value        TOT      Total        PC  Percentage               0
# 4   Value        TOT      Total        PC  Percentage               0
#
#   PowerCode  Reference Period Code  Reference Period  Value Flag Codes Flags
# ...

# %% [markdown]
# ## Parte 2 -  Preámbulo (5 puntos )
#
# - Presenta todo lo necesario para comenzar tu análisis de la información.
# - Todo deberá estar comentado para que el usuario final y puede ser entendido
#
#     ### Que voy a hacer?
#
#     - Buscar patrones
#     - Buscar relaciones
#     - Cosas curiosas de los datos
#
#     ### Que usare hoy ?
#
#     - Usaremos pandas para el analisis
#     - Usarems MATPLOTLIB.PYPLOT
#     - Usaremos numpy (para manipular informacion: sumar, restar, dividir, multiplicar)

# %% [markdown]
# ## Parte 3 - Análisis inicial (20 puntos)
#
# ### Presenta entrega el resultado y el código utilizado. Mientras más explícito, mejor. Mientras más bonito, mejor
#
# - 3.1 ¿Cuántos países hay en la base de datos? ¿Cuáles son?
# - 3.2 ¿Cuántos tipos de unidades se manejan?
# - 3.3 ¿Cuáles son los indicadores medidos? ¿Cuántos son?
# - 3.4 Descripción básica de los indicadores numéricos (estadística descriptiva)
# - 3.5 ¿Podemos eliminar algunas columnas de nuestra base de datos sin perder información importante?
#       Presenta la tabla y explica por qué eliminste dichas columnas
# - 3.6 ¿Puedes cambiar en nombre de las columnas a español?

# %% [markdown]
# ### 3.1 ¿Cuántos países hay en la base de datos? ¿Cuáles son?

# %%
#Numero de paises de mi base de datos OCDE e imprimir
num_paises=len(OCDE['Country'].unique())-1
print('Numero de paises de mi base de datos OCDE: ',num_paises)
# Out:
# Numero de paises de mi base de datos OCDE:  38

# %%
#Nombre de los paises de mi base de datos OCDE e imprimir
nombre_paises=OCDE['Country'].unique()
pd.DataFrame(nombre_paises)
# Out:
#                   0
# 0         Australia
# 1           Austria
# 2           Belgium
# 3            Canada
# 4    Czech Republic
# 5           Denmark
# 6           Finland
# 7            France
# 8           Germany
# 9            Greece
# 10          Hungary
# 11          Iceland
# 12          Ireland
# 13            Italy
# 14            Japan
# 15            Korea
# 16       Luxembourg
# 17           Mexico
# 18      Netherlands
# 19      New Zealand
# 20           Norway
# 21           Poland
# 22         Portugal
# 23  Slovak Republic
# 24            Spain
# 25           Sweden
# 26      Switzerland
# 27           Turkey
# 28   United Kingdom
# 29    United States
# 30           Brazil
# 31            Chile
# 32          Estonia
# 33           Israel
# 34           Latvia
# 35           Russia
# 36         Slovenia
# 37     South Africa
# 38     OECD - Total

# %% [markdown]
# ### 3.2 Cuantos tipos de unidades se manejan?

# %%
# Llamo las unidades de mi base
tipos_de_unidades=(OCDE['Unit'].unique())
pd.DataFrame(tipos_de_unidades)
# Out:
#                             0
# 0                  Percentage
# 1               Average score
# 2                       Ratio
# 3                   US Dollar
# 4                       Years
# 5  Micrograms per cubic metre
# 6                       Hours

# %% [markdown]
# ### 3.3 ¿Cuáles son los indicadores medidos? ¿Cuántos son?

# %%
# Llamar los indicadores de mi base
indicadores=(OCDE['Indicator'].unique())
pd.DataFrame(indicadores)
# Out:
#                                                     0
# 0                            Labour market insecurity
# 1   Stakeholder engagement for developing regulations
# 2                 Feeling safe walking alone at night
# 3                  Dwellings without basic facilities
# 4                                 Housing expenditure
# 5                                    Rooms per person
# 6            Household net adjusted disposable income
# 7                      Household net financial wealth
# 8                                     Employment rate
# 9                         Long-term unemployment rate
# 10                                  Personal earnings
# 11                         Quality of support network
# 12                             Educational attainment
# 13                                     Student skills
# 14                                 Years in education
# 15                                      Air pollution
# ...

# %%
num_indicadores=len(OCDE['Indicator'].unique())
print(num_indicadores)
# Out:
# 24

# %% [markdown]
#  ## 3.4 Descripción básica de los indicadores numéricos (estadística descriptiva)

# %%
# Descripción básica de los indicadores numéricos (estadística descriptiva)
OCDE.describe()
# Out:
#        PowerCode Code  Reference Period Code  Reference Period          Value
# count          3398.0                    0.0               0.0    3398.000000
# mean              0.0                    NaN               NaN    5353.200309
# std               0.0                    NaN               NaN   15832.099269
# min               0.0                    NaN               NaN       0.000000
# 25%               0.0                    NaN               NaN       7.000000
# 50%               0.0                    NaN               NaN      62.000000
# 75%               0.0                    NaN               NaN      91.000000
# max               0.0                    NaN               NaN  176076.000000

# %% [markdown]
# ### 3.5 ¿Podemos eliminar algunas columnas de nuestra base de datos sin perder información importante?
#           Presenta la tabla y explica por qué eliminste dichas columnas

# %%
# ¿Podemos eliminar algunas columnas de nuestra base de datos sin perder información importante? 
# Si podemos

#Creamos una nueva base de datos y eliminamos algunas columnas
OCDE2=OCDE.drop(['MEASURE','INEQUALITY','Unit Code','PowerCode Code','Reference Period Code','Flag Codes','Flags'], axis=1)

# %%
pd.DataFrame(OCDE2)

# Esta tabla ya esta mas limpia y puedo ver la informacion que realmente me interesa.
# Out:
#      LOCATION          Country INDICATOR  \
# 0         AUS        Australia   JE_LMIS
# 1         AUT          Austria   JE_LMIS
# 2         BEL          Belgium   JE_LMIS
# 3         CAN           Canada   JE_LMIS
# 4         CZE   Czech Republic   JE_LMIS
# 5         DNK          Denmark   JE_LMIS
# 6         FIN          Finland   JE_LMIS
# 7         FRA           France   JE_LMIS
# 8         DEU          Germany   JE_LMIS
# 9         GRC           Greece   JE_LMIS
# 10        HUN          Hungary   JE_LMIS
# 11        ISL          Iceland   JE_LMIS
# 12        IRL          Ireland   JE_LMIS
# 13        ITA            Italy   JE_LMIS
# 14        JPN            Japan   JE_LMIS
# 15        KOR            Korea   JE_LMIS
# 16        LUX       Luxembourg   JE_LMIS
# 17        MEX           Mexico   JE_LMIS
# 18        NLD      Netherlands   JE_LMIS
# 19        NZL      New Zealand   JE_LMIS
# 20        NOR           Norway   JE_LMIS
# 21        POL           Poland   JE_LMIS
# ...

# %% [markdown]
# ### 3.6 ¿Puedes cambiar en nombre de las columnas a español?

# %%
OCDE2.rename(columns={'LOCATION':'LOCACION','Country':'Pais','INDICATOR':'INDICADOR','Indicator':'Indicador','Measure':'Medida','Inequality':'Genero','Unit':'Unidad','PowerCode':'Codigo','Reference Period':'Periodo','Value':'Valor'})
# Out:
#      LOCACION             Pais INDICADOR  \
# 0         AUS        Australia   JE_LMIS
# 1         AUT          Austria   JE_LMIS
# 2         BEL          Belgium   JE_LMIS
# 3         CAN           Canada   JE_LMIS
# 4         CZE   Czech Republic   JE_LMIS
# 5         DNK          Denmark   JE_LMIS
# 6         FIN          Finland   JE_LMIS
# 7         FRA           France   JE_LMIS
# 8         DEU          Germany   JE_LMIS
# 9         GRC           Greece   JE_LMIS
# 10        HUN          Hungary   JE_LMIS
# 11        ISL          Iceland   JE_LMIS
# 12        IRL          Ireland   JE_LMIS
# 13        ITA            Italy   JE_LMIS
# 14        JPN            Japan   JE_LMIS
# 15        KOR            Korea   JE_LMIS
# 16        LUX       Luxembourg   JE_LMIS
# 17        MEX           Mexico   JE_LMIS
# 18        NLD      Netherlands   JE_LMIS
# 19        NZL      New Zealand   JE_LMIS
# 20        NOR           Norway   JE_LMIS
# 21        POL           Poland   JE_LMIS
# ...

# %% [markdown]
# ## Parte 4 - Búsqueda de datos (30 puntos)

# %%
Imprime el los datos o Dataframes ( ¡Panditas! :D ) que se te solicitan (Recuerden no modificar el original) 
y entregenme sus observacioens de los datos (pueden usar gráficas
 
    - 4.1 Imprime los valores de los indicadores para México, eliminando la columna del país) 
    - 4.2 Muestra los países con esperanza de vida femenina mayor al promedio general y sus datos 
    - 4.3 Muestra los países cuya seguridad al caminar en la noche es menor al promedio y sus valores 
    - 4.4 Muestra las columnas de los datos completos de los países con mejor satisfacción de vida.

# %% [markdown]
# ### 4.1 Imprime los valores de los indicadores para México, eliminando la columna del país)

# %%
# Aqui estoy creando un nuevo panda para modificar y eliminar columnas
OCDE2=OCDE.set_index('LOCATION')
pd.DataFrame(OCDE2)
# Out:
#                   Country INDICATOR  \
# LOCATION
# AUS             Australia   JE_LMIS
# AUT               Austria   JE_LMIS
# BEL               Belgium   JE_LMIS
# CAN                Canada   JE_LMIS
# CZE        Czech Republic   JE_LMIS
# DNK               Denmark   JE_LMIS
# FIN               Finland   JE_LMIS
# FRA                France   JE_LMIS
# DEU               Germany   JE_LMIS
# GRC                Greece   JE_LMIS
# HUN               Hungary   JE_LMIS
# ISL               Iceland   JE_LMIS
# IRL               Ireland   JE_LMIS
# ITA                 Italy   JE_LMIS
# JPN                 Japan   JE_LMIS
# KOR                 Korea   JE_LMIS
# LUX            Luxembourg   JE_LMIS
# MEX                Mexico   JE_LMIS
# NLD           Netherlands   JE_LMIS
# NZL           New Zealand   JE_LMIS
# NOR                Norway   JE_LMIS
# POL                Poland   JE_LMIS
# PRT              Portugal   JE_LMIS
# SVK       Slovak Republic   JE_LMIS
# ...

# %%
# BORRO LA COLUMNA COUNTRY
OCDE3=OCDE2.drop(['Country'], axis=1)

# %%
pd.DataFrame(OCDE3)
# Out:
#          INDICATOR                                  Indicator MEASURE Measure  \
# LOCATION
# AUS        JE_LMIS                   Labour market insecurity       L   Value
# AUT        JE_LMIS                   Labour market insecurity       L   Value
# BEL        JE_LMIS                   Labour market insecurity       L   Value
# CAN        JE_LMIS                   Labour market insecurity       L   Value
# CZE        JE_LMIS                   Labour market insecurity       L   Value
# DNK        JE_LMIS                   Labour market insecurity       L   Value
# FIN        JE_LMIS                   Labour market insecurity       L   Value
# FRA        JE_LMIS                   Labour market insecurity       L   Value
# DEU        JE_LMIS                   Labour market insecurity       L   Value
# GRC        JE_LMIS                   Labour market insecurity       L   Value
# HUN        JE_LMIS                   Labour market insecurity       L   Value
# ...

# %%
MEXICO=OCDE3.loc['MEX']
MEXICO.head()
# Out:
#           INDICATOR                                          Indicator  \
# LOCATION
# MEX         JE_LMIS                           Labour market insecurity
# MEX         CG_SENG  Stakeholder engagement for developing regulations
# MEX         CG_SENG  Stakeholder engagement for developing regulations
# MEX         CG_SENG  Stakeholder engagement for developing regulations
# MEX       PS_FSAFEN                Feeling safe walking alone at night
#
#          MEASURE Measure INEQUALITY Inequality Unit Code           Unit  \
# LOCATION
# MEX            L   Value        TOT      Total        PC     Percentage
# MEX            L   Value        TOT      Total   AVSCORE  Average score
# MEX            L   Value         MN        Men   AVSCORE  Average score
# MEX            L   Value        WMN      Women   AVSCORE  Average score
# MEX            L   Value        TOT      Total        PC     Percentage
#
#           PowerCode Code PowerCode  Reference Period Code  Reference Period  \
# ...

# %% [markdown]
# ### 4.2 Muestra los países c/esperanza de vida femenina > al promedio general y sus datos

# %%
# Creo una nueva base de datos
Expectativa_de_vida=OCDE

# %%
# Llamo la columna Inequality que me muestra hombre, mujer y total
Indice_Expectativa=Expectativa_de_vida.set_index('Inequality')
Indice_Expectativa
# Out:
#            LOCATION          Country INDICATOR  \
# Inequality
# Total           AUS        Australia   JE_LMIS
# Total           AUT          Austria   JE_LMIS
# Total           BEL          Belgium   JE_LMIS
# Total           CAN           Canada   JE_LMIS
# Total           CZE   Czech Republic   JE_LMIS
# Total           DNK          Denmark   JE_LMIS
# Total           FIN          Finland   JE_LMIS
# Total           FRA           France   JE_LMIS
# Total           DEU          Germany   JE_LMIS
# Total           GRC           Greece   JE_LMIS
# Total           HUN          Hungary   JE_LMIS
# Total           ISL          Iceland   JE_LMIS
# Total           IRL          Ireland   JE_LMIS
# Total           ITA            Italy   JE_LMIS
# Total           JPN            Japan   JE_LMIS
# Total           KOR            Korea   JE_LMIS
# Total           LUX       Luxembourg   JE_LMIS
# Total           MEX           Mexico   JE_LMIS
# Total           NLD      Netherlands   JE_LMIS
# ...

# %%
# llamo unicamente las filas WOMAN
Indice_Expectativa_Mujer=Indice_Expectativa.loc['Women']

# %%
Indice_Expectativa_Mujer
# Out:
#            LOCATION          Country INDICATOR  \
# Inequality
# Women           AUS        Australia   CG_SENG
# Women           AUT          Austria   CG_SENG
# Women           BEL          Belgium   CG_SENG
# Women           CAN           Canada   CG_SENG
# Women           CZE   Czech Republic   CG_SENG
# Women           DNK          Denmark   CG_SENG
# Women           FIN          Finland   CG_SENG
# Women           FRA           France   CG_SENG
# Women           DEU          Germany   CG_SENG
# Women           GRC           Greece   CG_SENG
# Women           HUN          Hungary   CG_SENG
# Women           ISL          Iceland   CG_SENG
# Women           IRL          Ireland   CG_SENG
# Women           ITA            Italy   CG_SENG
# Women           JPN            Japan   CG_SENG
# Women           KOR            Korea   CG_SENG
# Women           LUX       Luxembourg   CG_SENG
# Women           MEX           Mexico   CG_SENG
# Women           NLD      Netherlands   CG_SENG
# ...

# %%
#Aqui saco el numero de registros de mujeres
num_woman=len(Indice_Expectativa_Mujer)
print('Numero de mujeres de mi base: ',num_woman)

prom_num_woman=np.mean(Indice_Expectativa_Mujer['Value'])
print('Promedio de expectativa de vida de mujeres: ',prom_num_woman)
# Out:
# Numero de mujeres de mi base:  890
# Promedio de expectativa de vida de mujeres:  4692.162977528093

# %%
MARISSA:


valores_mujer = mujeres_expectativa['Value']
## Pregunta cuáles países tienen expectativa de vida mayor al promedio

#Parámetro de filtro = ['Value']restricción
promedio_vida=82.24
total=valores_mujer.count()

P_V = sum(valores_mujer>promedio_vida)
p_promedio = P_V/total

print("Existen ", P_V, " países con expectativa mayor al promedio", "de un total de ", total)
print("Esto representa el ", round(p_promedio,4)*100, "% del total de la muestra, según un parámetro promedio_vida= ",promedio_vida)

# %%
MARISSA:

#Para conocer cuáles países son los de mejor esperanza de vida (arriba del promedio)
#mujeres_expectativa=mujeres_expectativa.drop(["MEASURE", "INEQUALITY","Unit Code","PowerCode Code","Reference Period Code","Flag Codes","Flags"],axis=1)
Expectativa_arriba_media = mujeres_expectativa[mujeres_expectativa['Value'] > 82.24 ]
#Puedo acomodar el set de datos, de mayor a menor expectativa... 
Expectativa_arriba_sorteada=Expectativa_arriba_media.sort_values(by=['Value'],axis=0,ascending=False)
pd.DataFrame(Expectativa_arriba_sorteada)

# %%
### Parte 5 - Información gráfica (40 puntos + 20 puntos extra)

Entrega la gráficas con títulos, nombres en los ejes y mejora la presentación de las mismas (colores, número de cajas en el histograma, valores extra) . Así mismo deberán entregar la interpretación de las mismas. 

- Realiza 3 análisis de la relación entre dos variables. 

- Realizar 2 análisis donde se necesite usar histogramas. 

- Presenta un análisis utilizando una gráfica de barras de los indicadores para múltiples paises. (PUNTOS EXTRA) 

- Realicen una análisis de correlación para 4 variables (PUNTOS EXTRA) (¿Scatter or density?)

### Parte 6 - Referencias para la tarea: 

- http://benalexkeen.com/correlation-in-python/
- https://github.com/jakevdp/PythonDataScienceHandbook/tree/be23269c7eb119e093a6d5ce91e464f5e686d9ab/notebooks
- https://machinelearningmastery.com/visualize-machine-learning-data-python-pandas/
