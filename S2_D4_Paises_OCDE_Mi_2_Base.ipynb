# %% [markdown]
# ## BASE DE DATOS 2: El regreso de Ric

# %%
# Importar librerias necesarias (no importa el orden)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
OCDE=pd.read_csv('BLI.csv')
OCDE.head()
# Out:
#   LOCATION         Country INDICATOR                 Indicator MEASURE  \
# 0      AUS       Australia   JE_LMIS  Labour market insecurity       L
# 1      AUT         Austria   JE_LMIS  Labour market insecurity       L
# 2      BEL         Belgium   JE_LMIS  Labour market insecurity       L
# 3      CAN          Canada   JE_LMIS  Labour market insecurity       L
# 4      CZE  Czech Republic   JE_LMIS  Labour market insecurity       L
#
#   Measure INEQUALITY Inequality Unit Code        Unit  PowerCode Code  \
# 0   Value        TOT      Total        PC  Percentage               0
# 1   Value        TOT      Total        PC  Percentage               0
# 2   Value        TOT      Total        PC  Percentage               0
# 3   Value        TOT      Total        PC  Percentage               0
# 4   Value        TOT      Total        PC  Percentage               0
#
#   PowerCode  Reference Period Code  Reference Period  Value Flag Codes Flags
# ...

# %%
# Numero de registros que tiene
len(OCDE)
# Out:
# 3398

# %%
OCDE['Indicator'].unique()

#Esta dirigida a una poblacion, modo de vida, calidad de vida. hay 24 indicadores.
# Out:
# array(['Labour market insecurity',
#        'Stakeholder engagement for developing regulations',
#        'Feeling safe walking alone at night',
#        'Dwellings without basic facilities', 'Housing expenditure',
#        'Rooms per person', 'Household net adjusted disposable income',
#        'Household net financial wealth', 'Employment rate',
#        'Long-term unemployment rate', 'Personal earnings',
#        'Quality of support network', 'Educational attainment',
#        'Student skills', 'Years in education', 'Air pollution',
#        'Water quality', 'Voter turnout', 'Life expectancy',
#        'Self-reported health', 'Life satisfaction', 'Homicide rate',
#        'Employees working very long hours',
#        'Time devoted to leisure and personal care'], dtype=object)

# %%
# Cuantos indicadores hay 
len(OCDE['Indicator'].unique())
# Out:
# 24

# %%
len(OCDE['Country'].unique())
# Out:
# 39

# %%
OCDE['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czech Republic',
#        'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Iceland', 'Ireland', 'Italy', 'Japan', 'Korea', 'Luxembourg',
#        'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland',
#        'Portugal', 'Slovak Republic', 'Spain', 'Sweden', 'Switzerland',
#        'Turkey', 'United Kingdom', 'United States', 'Brazil', 'Chile',
#        'Estonia', 'Israel', 'Latvia', 'Russia', 'Slovenia',
#        'South Africa', 'OECD - Total'], dtype=object)

# %%
OCDE2=OCDE.drop(['MEASURE','INEQUALITY','Unit Code','PowerCode Code','Reference Period Code','Flag Codes','Flags'], axis=1)

# %%
pd.DataFrame(OCDE2)
# Out:
#      LOCATION          Country INDICATOR  \
# 0         AUS        Australia   JE_LMIS
# 1         AUT          Austria   JE_LMIS
# 2         BEL          Belgium   JE_LMIS
# 3         CAN           Canada   JE_LMIS
# 4         CZE   Czech Republic   JE_LMIS
# 5         DNK          Denmark   JE_LMIS
# 6         FIN          Finland   JE_LMIS
# 7         FRA           France   JE_LMIS
# 8         DEU          Germany   JE_LMIS
# 9         GRC           Greece   JE_LMIS
# 10        HUN          Hungary   JE_LMIS
# 11        ISL          Iceland   JE_LMIS
# 12        IRL          Ireland   JE_LMIS
# 13        ITA            Italy   JE_LMIS
# 14        JPN            Japan   JE_LMIS
# 15        KOR            Korea   JE_LMIS
# 16        LUX       Luxembourg   JE_LMIS
# 17        MEX           Mexico   JE_LMIS
# 18        NLD      Netherlands   JE_LMIS
# 19        NZL      New Zealand   JE_LMIS
# 20        NOR           Norway   JE_LMIS
# 21        POL           Poland   JE_LMIS
# ...

# %% [markdown]
# Mis preguntas:
#
# - Sentirse seguro caminando solo por la noche
# - Viviendas sin instalaciones básicas
# - Gasto en vivienda
# - Habitaciones por persona
# - Ingresos disponibles ajustados netos del hogar
# - Riqueza financiera neta de los hogares
# - tasa de empleo
# - Tasa de desempleo a largo plazo
# - Ingresos personales
# - Calidad de la red de apoyo
# - Logro educativo
# - Habilidades estudiantiles
# - Años de educación
# - Contaminación del aire
# - Calidad del agua
# - Asistencia electoral
# - Esperanza de vida
# - Satisfacción con la vida
# - Tasa de homicidios
# - Empleados trabajando horas muy largas
# - Tiempo dedicado al ocio y al cuidado personal

# %%
OCDE2=OCDE.set_index('Country')
OCDE2.head()
# Out:
#                LOCATION INDICATOR                 Indicator MEASURE Measure  \
# Country
# Australia           AUS   JE_LMIS  Labour market insecurity       L   Value
# Austria             AUT   JE_LMIS  Labour market insecurity       L   Value
# Belgium             BEL   JE_LMIS  Labour market insecurity       L   Value
# Canada              CAN   JE_LMIS  Labour market insecurity       L   Value
# Czech Republic      CZE   JE_LMIS  Labour market insecurity       L   Value
#
#                INEQUALITY Inequality Unit Code        Unit  PowerCode Code  \
# Country
# Australia             TOT      Total        PC  Percentage               0
# Austria               TOT      Total        PC  Percentage               0
# Belgium               TOT      Total        PC  Percentage               0
# Canada                TOT      Total        PC  Percentage               0
# Czech Republic        TOT      Total        PC  Percentage               0
#
# ...

# %%
OCDE2.loc['Austria']
# Out:
#         LOCATION  INDICATOR  \
# Country
# Austria      AUT    JE_LMIS
# Austria      AUT    CG_SENG
# Austria      AUT    CG_SENG
# Austria      AUT    CG_SENG
# Austria      AUT  PS_FSAFEN
# Austria      AUT  PS_FSAFEN
# Austria      AUT  PS_FSAFEN
# Austria      AUT    HO_BASE
# Austria      AUT    HO_BASE
# Austria      AUT    HO_BASE
# Austria      AUT    HO_HISH
# Austria      AUT    HO_HISH
# Austria      AUT    HO_HISH
# Austria      AUT    HO_NUMR
# Austria      AUT    HO_NUMR
# Austria      AUT    HO_NUMR
# Austria      AUT    IW_HADI
# Austria      AUT    IW_HADI
# Austria      AUT    IW_HADI
# Austria      AUT    IW_HADI
# Austria      AUT    IW_HADI
# Austria      AUT    IW_HNFW
# Austria      AUT    IW_HNFW
# Austria      AUT    IW_HNFW
# Austria      AUT    JE_EMPL
# Austria      AUT    JE_EMPL
# Austria      AUT    JE_EMPL
# Austria      AUT    JE_EMPL
# Austria      AUT    JE_EMPL
# Austria      AUT    JE_LTUR
# ...          ...        ...
# ...

# %%
#Generacion de Panda (mi panda es OCDE csv), Aqui estoy tomando solo una columna de mi panda:
#energia=spotify['energy']

OCDE2=OCDE.set_index('Indicator')
OCDE2.head()
# Out:
#                          LOCATION         Country INDICATOR MEASURE Measure  \
# Indicator
# Labour market insecurity      AUS       Australia   JE_LMIS       L   Value
# Labour market insecurity      AUT         Austria   JE_LMIS       L   Value
# Labour market insecurity      BEL         Belgium   JE_LMIS       L   Value
# Labour market insecurity      CAN          Canada   JE_LMIS       L   Value
# Labour market insecurity      CZE  Czech Republic   JE_LMIS       L   Value
#
#                          INEQUALITY Inequality Unit Code        Unit  \
# Indicator
# Labour market insecurity        TOT      Total        PC  Percentage
# Labour market insecurity        TOT      Total        PC  Percentage
# Labour market insecurity        TOT      Total        PC  Percentage
# Labour market insecurity        TOT      Total        PC  Percentage
# Labour market insecurity        TOT      Total        PC  Percentage
#
# ...

# %%
Habilidades_estudiantiles=OCDE2.loc['Student skills']
pd.DataFrame(Habilidades_estudiantiles)
# Out:
#                LOCATION          Country INDICATOR MEASURE Measure INEQUALITY  \
# Indicator
# Student skills      AUS        Australia   ES_STCS       L   Value        TOT
# Student skills      AUT          Austria   ES_STCS       L   Value        TOT
# Student skills      BEL          Belgium   ES_STCS       L   Value        TOT
# Student skills      CAN           Canada   ES_STCS       L   Value        TOT
# Student skills      CZE   Czech Republic   ES_STCS       L   Value        TOT
# Student skills      DNK          Denmark   ES_STCS       L   Value        TOT
# Student skills      FIN          Finland   ES_STCS       L   Value        TOT
# Student skills      FRA           France   ES_STCS       L   Value        TOT
# Student skills      DEU          Germany   ES_STCS       L   Value        TOT
# Student skills      GRC           Greece   ES_STCS       L   Value        TOT
# Student skills      HUN          Hungary   ES_STCS       L   Value        TOT
# ...

# %%
Habilidades_estudiantiles.plot(kind='hist')
plt.xlabel(' ')
print()
plt.ylabel(' ')
plt.title('Habilidadedes Estudiantiles ')
plt.show()

#,bins=30

# %%
#canciones_future=s2.loc['Future']
#canciones_future[['tempo']]

VALOR MAXIMO Y MINIMO 
PENDIENTE
# Out:
#  En habilidades: El VALOR MAXIMO es:  Value El VALOR MINIMO es:  Country
